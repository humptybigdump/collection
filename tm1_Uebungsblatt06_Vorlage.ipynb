# %% [markdown]
# <h1> Technische Mechanik I - WS 24/25</h1>
#
# <h2> Rechneraufgabe Übungsblatt 6 </h2>
#
# <h3> Institut für Technische Mechanik (Prof. Böhlke) </h3>
#
# <h4> Karlsruher Institut für Technologie (KIT) </h4>
#
# <b>Allgemeine Hinweise zur Bearbeitung von Rechnerhausaufgaben:</b>
#
# Alle verwendeten Einheiten sind <b>[N]</b> für Kräfte und <b>[mm]</b> (in dieser Aufgabe) für Längen. Abgeleitete Einheiten wie z.B. <b>[Nm]</b> ergeben sich aus den Definitionsgleichungen der jeweiligen Größen. Sofern nicht in der Aufgabenstellung gefordert, wird im Quellcode auf die explizite Verwendung von Einheiten verzichtet. Bei der Bearbeitung der Aufgabe ist dennoch kontinuierlich auf Konsistenz der Maßzahlen und Maßeinheiten zu achten. Halten Sie sich durchgehend an in der Aufgabenstellung vorgegebene Bezeichnungen und Koordinatensysteme. Falls im Code Namenskonventionen eingeführt werden, sind diese ebenfalls durchgängig einzuhalten.
#
# **Neue SymPy-Befehle:** `diff`, `piecewise`, `dsolve`, `plot`.
#
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# <figure id="rha_abb1">
# <div style="width: 95%; margin-left: auto;  margin-right: auto;">
#
# ![ueb06.png](attachment:1e612d28-134b-4a15-8f07-36076ae06e3a.png)
#
# <figcaption><span id="rha_abb1" label="rha_abb1"></span> Abb. R.1: Balken mit
# Streckenlast <span class="math inline"><em>q</em>(<em>x</em>)</span>
# (links) und Balken mit Einzelkraft <span
# class="math inline"><em>F</em></span> und Einzelmoment <span
# class="math inline"><em>M</em></span> (rechts)</figcaption>
# </div>
# </figure>
# </span>

# %%
import sympy as sympy

# %% [markdown]
# # Teilaufgabe 1
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) Gegeben ist der in Abb. R.1 links dargestellte Balken, der durch die Streckenlast $$q(x)=\frac{q_0}{2}\cos\left(\pi\frac{2x-l}{l}\right)+q_0\left(\frac{2x}{l}-1\right)^2$$ belastet wird. Lösen Sie folgende Aufgabenstellungen für dieses System.
# </span>
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) 1) Berechnen Sie die Lagerreaktionen in den Lagern $A$ und $B$ durch Lösen eines Gleichungssystems aus den Gleichgewichtsbedingungen in SymPy. Zeichnen Sie die dafür notwendigen Freikörperbilder (auf Papier).
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) 2) Berechnen Sie den Querkraftverlauf $Q_z(x)$ und den Biegemomentenverlauf $M_y(x)$ mittels Integration der Schnittgrößendifferentialgleichungen. **Hinweis**: Stellen Sie dazu ein System von Differentialgleichungen auf und lösen Sie dieses zunächst ohne Randbedingungen unter Verwendung des Kommandos `dsolve`. Wählen Sie anschließend geeignete Randbedingungen und lösen Sie das um diese erweiterte System erneut mit `dsolve`.
# </span>
#
# ##
# ---

# %% [markdown]
# **Hinweis:** In dieser Aufgabe müssen die Differentialgleichung zunächst ohne Randbedingungen gelöst werden. Bestimmen Sie die Randbedingunen anschließend mit `solve`.

# %% [markdown]
# Integrationskonstanten einsetzen

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) 3) Verifizieren Sie ihre Lösung, indem Sie die berechneten Schnittgrößen an den Rändern ausrechnen und mit den in 1.A) berechneten Lagerreaktionen vergleichen. Geben Sie dafür die notwendigen Bedingungen an (auf Papier).
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) 4) Stellen Sie die Verläufe der Streckenlast, der Querkraft und des Moments für $l=1 \,{\rm m}$, $q_0=200 \,{\rm N/m}$ grafisch dar.
# </span>
#
# ##
# ---

# %% [markdown]
# Visualisierung der Streckenlast, **Hinweis:** Stellen Sie den Ausschnitt der Funktion mit dem Tupel `(x,0,1)` ein. Das Tupel muss direkt auf die Funktion folgen.

# %% [markdown]
# # Teilaufgabe 2
# <span style="font-family:serif; font-size:1.5em;">
#
# 2)  Gegeben sei nun der in Abb. R.1 rechts dargestellte Balken belastet durch eine Einzelkraft $F$ bei $x=l/4$ und ein Einzelmoment $M$ bei $x=l/2$.
#     Lösen Sie folgende Aufgabenstellungen für dieses System.
# </span>
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
#
# 2. 1. Berechnen Sie die Lagerreaktionen in den Lagern $A$ und $B$ **handschriftlich**. Zeichnen Sie die dafür notwendigen Freikörperbilder (auf Papier).
#
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 2) 2) Berechnen Sie den Querkraftverlauf $Q_z(x)$ und den Biegemomentenverlauf $M_y(x)$ aus den Gleichgewichtsbedingungen **handschriftlich**.
# Zeichnen Sie die dafür notwendigen Freikörperbilder (auf Papier).
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 2) 3)  Visualisieren Sie den Querkraft- und Momentenverlauf für $l=1 \,{\rm m}$, $F=100 \,{\rm N}$ und $M=50 \,{\rm Nm}$.
# </span>
#
#
#
# ##
# ---

# %% [markdown]
# # Teilaufgabe 3
# <span style="font-family:serif; font-size:1.5em;">
#
# 3) Aufgrund der Linearität der zugrundeliegenden Differentialgleichungen gilt das **Superpositionsprinzip**. Die Einzellösungen der beiden Belastungsfälle können zu einer Gesamtlösung überlagert werden. <br> Beispiel: Superposition der Querkraftverläufe für die Systeme in Abb. R.1 links und rechts R.1: $Q_z^{\rm LR}(x)=Q_z^{\rm L}(x)+Q_z^{\rm R}(x)$ <br> Lösen Sie folgende Aufgabenstellungen für das zusammengesetzte System.
#
# </span>
#
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 3) 1) Visualisieren Sie den Querkraftverlauf $Q_z^{\rm LR}(x)$ und den Biegemomentenverlauf $M_y^{\rm LR}(x)$ für das zusammengesetzte System unter Verwendung der in Aufgabe 1.B) und Aufgabe 2.B) bestimmten Schnittgrößen und der in Aufgabe 1.D) und Aufgabe 2.C) genannten Zahlenwerte.
#
# </span>
#
#
#
# ##
# ---
