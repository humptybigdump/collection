# %% [markdown]
# <h1> Technische Mechanik I - WS 24/25</h1>
#
# <h2> Rechneraufgabe Übungsblatt 5 </h2>
#
# <h3> Institut für Technische Mechanik (Prof. Böhlke) </h3>
#
# <h4> Karlsruher Institut für Technologie (KIT) </h4>
#
# <b>Allgemeine Hinweise zur Bearbeitung von Rechnerhausaufgaben:</b>
#
# Alle verwendeten Einheiten sind <b>[N]</b> für Kräfte und <b>[mm]</b> (in dieser Aufgabe) für Längen. Abgeleitete Einheiten wie z.B. <b>[Nm]</b> ergeben sich aus den Definitionsgleichungen der jeweiligen Größen. Sofern nicht in der Aufgabenstellung gefordert, wird im Quellcode auf die explizite Verwendung von Einheiten verzichtet. Bei der Bearbeitung der Aufgabe ist dennoch kontinuierlich auf Konsistenz der Maßzahlen und Maßeinheiten zu achten. Halten Sie sich durchgehend an in der Aufgabenstellung vorgegebene Bezeichnungen und Koordinatensysteme. Falls im Code Namenskonventionen eingeführt werden, sind diese ebenfalls durchgängig einzuhalten.
#
# **Neue  SymPy-Befehle**: `Symbol`, `solve`, `subs`, `Eq`, Listen
# $[\ldots]$.
#
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# Die in Abbildung 1 dargestellte vordere Hälfte eines Sägebocks,
# bestehend aus den Beinen 1 und 2, wird durch ein Rundholz anteilig mit
# der Gewichtskraft $G$ belastet. Der Sägebock hat die Abmessungen $a$,
# $b$ und $l$. Die beiden masselosen Beine schließen einen Winkel von
# $2\alpha$ ein und sind über ein masseloses Seil zwischen den Punkten B
# und C miteinander verbunden. Es wirkt die Erdbeschleunigung $g$.\
# *Hinweis*: In der gesamten Aufgabe soll ausschließlich die dargestellte
# vordere Hälfte des Sägebocks betrachtet werden.
#
# <figure>
# <div style="width: 45%; margin-left: auto;  margin-right: auto;">
# <p>
#
# ![ueb05.png](attachment:30495efa-5d08-46f6-9788-dbac88192b26.png)
#
# </p>
#
# </div>
# <figcaption>Abbildung 1: Sägebockhälfte, belastet durch anteilige Gewichtskraft $G$</figcaption>
# </figure>
#
# Bearbeiten Sie die folgenden Teilaufgaben.
#
# </span>

# %%
import sympy as sympy

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) Schneiden Sie die Beine 1 und 2 sowie das Rundholz und das Seil
# frei und erstellen Sie **handschriftlich** die vier vollständigen
# Freikörperbilder. Ersetzen Sie dabei die Verbindungsbolzen in den
# Punkten A bis C durch die dort wirkenden Lagerreaktionskräfte. Weiterhin
# soll angenommen werden, dass an den Auflagepunkten des Rundholzes nur
# senkrecht zum jeweiligen Bein wirkende Kräfte übertragen werden können.
# Führen Sie darum diese Reaktionskräfte als senkrecht zum jeweiligen Bein
# orientierte Kräfte ein.
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 2) Stellen Sie alle Kraftgrößen **dreidimensional** in vektorieller
# Form dar. Berücksichtigen Sie dabei für die Normalkräfte notwendige
# Winkelbeziehungen.
#
# </span>
#
# ##
# ---

# %% [markdown]
# Definition der Symbole

# %% [markdown]
# Definition der Vektoren

# %%
null_vector = sympy.Matrix([0,0,0]);

A = 
B = 
C =
D =
E =
G_K = 
N_1 =
N_2 =
# Out:
#   Cell In[2], line 3
#     A =
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 3) Stellen Sie die Gleichgewichtsbedingungen in den einzelnen
# Teilsystemen für die Kräfte in vektorieller Form dar. Stellen Sie
# weiterhin die Gleichgewichtsbedingungen für die Momente bezüglich Punkt
# A als skalare Gleichungen auf.
#
# </span>
#
# ##
# ---

# %% [markdown]
# Definition der Kräftegleichgewichte:

# %%
force_equilibrium_1 =

# %% [markdown]
# Definition der zusätzlichen Momentengleichgewichte:

# %%
moment_equilibrium_1 =

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 4) Lösen Sie alle aus den vektoriellen Gleichgewichtsbedingungen
# extrahierten skalaren Gleichungen symbolisch mit Hilfe des Befehls `solve`.
# </span>
#
# ##
# ---

# %% [markdown]
# Definition des Gleichungssystems

# %%
equations =

# %% [markdown]
# Definition einer Menge der Unbekannten

# %%
unnkowns =

# %% [markdown]
# Lösen des Systems

# %%
solutions =

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 5) Berechnen Sie alle Reaktionsgrößen unter Berücksichtigung der
# Einheiten für folgende Abmessungen des Sägebocks und die auf der
# dargestellten Hälfte des Sägebocks lastende Masse des Rundholzes $m_0$:\
# $a=0.7\,{\rm m}$, $b=0.45\,{\rm m}$, $l=1.2\,{\rm m}$, $\alpha=10$°,
# $m_0=100\,{\rm kg}$, $g\approx9.81 \,{\rm m/s^2}$.
#
# </span>
#
# ##
# ---

# %% [markdown]
# Definitionen des Zahlenbeispiels als Liste von Substitutionen

# %% [markdown]
# Auswertung der Reaktionsgrößen

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 6) Berechnen Sie die maximal zulässige Masse $m_0$ des Rundholzes,
# wenn das Seil mit maximal $2\,{\rm kN}$ beansprucht werden darf.
# </span>
#
# ##
# ---

# %% [markdown]
# Definition der maximal zulässigen Seilkraft und aufstellen eines Gleichungssystems

# %%
C_max =
