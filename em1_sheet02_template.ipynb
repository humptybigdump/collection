# %% [markdown]
# <h1>Enigneering Mechanics I - Winter Term 24/25</h1>
#
# <h2>Python Sheet 2</h2>
#
# <h3>Institut für Technische Mechanik (Prof. Böhlke)</h3>
#
# <h4>Karlsruhe Institute of Technology (KIT)</h4>
#
# <b>General Guidelines for Completing Computer Exercises:</b>
#
# All units used are <b>[N]</b> for forces and <b>[mm]</b> (in this task) for lengths. Derived units, such as <b>[Nm]</b>, are determined by the defining equations of the respective quantities. Unless explicitly required by the task, units are not used explicitly in the source code. Nevertheless, be mindful of consistent numerical values and units throughout the exercise. Consistently follow the designations and coordinate systems provided in the task. If naming conventions are introduced in the code, they should be applied consistently.
#
# **New SymPy commands**: `Symbol`, `subs`, `dot`, `cross`, `solve`, `Eq`, `sqrt`, `simplify`, `evalf`, `cos`, `sin`
#
#
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# The reference system
# $\left\{ \mathcal{O}, \boldsymbol{ e}_x, \boldsymbol{ e}_y, \boldsymbol{ e}_z \right\}$
# is given, where $\left\{ \boldsymbol{ e}_x, \boldsymbol{ e}_y, \boldsymbol{ e}_z \right\}$
# represents an orthonormal basis. Additionally known are the magnitude of the
# force $\boldsymbol{ F}$ with $F=| \boldsymbol{ F} |= 2000\,{\rm N}$ and the
# fixed angle $\alpha = 18^{\circ}$. For the fixed angle $\theta$,
# $0^{\circ} <\theta < 72^{\circ}$ holds. The directions of the upper support (AB)
# and the lower support (AC) are described by the unit vectors
# $\boldsymbol{ e}_o$ and $\boldsymbol{ e}_u$.
#
# <figure>
# <div style="width: 50%; margin-left: auto; margin-right: auto;">
#
# ![image.png](attachment:7da27e12-95ba-4a74-a124-a34be700c421.png)
#
# </p>
# </div>
# <figcaption>Fig. R.1: System with two fixed supports (Source: <em>Hibbeler,
# R. C., 2005. Technische Mechanik 1 - Statik. Springer</em>)</figcaption>
# </figure>
#
# </span>

# %%
import sympy as sympy

# %% [markdown]
# # Subtasks

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) Show that the following relationship holds:
# $$ \sin(\alpha +\theta)\cos\alpha-\cos(\alpha +\theta)\sin\alpha=\sin\theta  \tag{R.1}$$
# (*handwritten solution required!*).
#
# </span>

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 2) Define the unit vectors $\boldsymbol{e}_o$, $\boldsymbol{e}_u$, and $\boldsymbol{e}_z$ in SymPy, as well as the force vector $\boldsymbol{F}$, in terms of the given orthonormal basis
# $\left\{\boldsymbol{ e}_x,\,\boldsymbol{ e}_y,\,\boldsymbol{ e}_z\right\}$ and the angles $\alpha$ and $\theta$. Use these defined unit vectors as much as possible in the following subtasks, and, if necessary, substitute numerical values only at the end of each subtask.
#
# </span>

# %% [markdown]
# First, define the symbols:

# %%
alpha = 
theta = 
F =

# %%
e_u = 
e_o = 
e_z = 
F_vector = 

display(e_u, e_o, e_z, F_vector)

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 3) Prove mathematically that the vectors
# $\left\{ \boldsymbol{ e}_o, \boldsymbol{ e}_u, \boldsymbol{ e}_z\right\}$ form a basis.
#
# </span>

# %% [markdown]
# Use `dot` and `cross`

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 4) The projection of $\boldsymbol{ F}$ in the direction of
# $\boldsymbol{ e}_o$ should have the value $F_o=-\sqrt{2}F/{2}$. Calculate
# the angle $\theta$ (check result: $\theta=27^{\circ}$).
#
# </span>

# %% [markdown]
# Also express $\theta$ in degrees.

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 5) Decompose the force $\boldsymbol{ F}$ into the oblique basis
# $\left\{\boldsymbol{ e}_o, \boldsymbol{ e}_u, \boldsymbol{ e}_z\right\}$ as follows:
# $$\boldsymbol{ F}= F_o\boldsymbol{ e}_o + F_u\boldsymbol{ e}_u + F_z\boldsymbol{ e}_z \tag{R.2}$$
# using vector calculus. For this, apply the formulas for an oblique basis given in the lecture notes.
#
# </span>

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 6) To verify your results, first formulate the system of equations corresponding to equation (R.2) and then solve it. Finally, check your solution using the `simplify` command.
#
# </span>

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 7) Calculate the moment vector $\boldsymbol{ M}_C$ of the force
# $\boldsymbol{ F}$ with respect to point $C$, given that the length of support AC
# is $l=0.5\,{\rm m}$.
#
# </span>

# %% [markdown]
# Formulating the vector from point C to the force application point A:

# %%
r_ca =

# %% [markdown]
# To calculate \( M_c \), substitute the given values \( F \) in N, \( l \) in m, and \( \alpha \) in radians. Finally, output the numerical result using `evalf()`.
