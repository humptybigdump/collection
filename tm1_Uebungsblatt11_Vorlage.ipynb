# %% [markdown]
# <h1> Technische Mechanik I - WS 24/25</h1>
#
# <h2> Rechneraufgabe Übungsblatt 11 </h2>
#
# <h3> Institut für Technische Mechanik (Prof. Böhlke) </h3>
#
# <h4> Karlsruher Institut für Technologie (KIT) </h4>
#
# <b>Allgemeine Hinweise zur Bearbeitung von Rechnerhausaufgaben:</b>
#
# Alle verwendeten Einheiten sind <b>[N]</b> für Kräfte und <b>[mm]</b> (in dieser Aufgabe) für Längen. Abgeleitete Einheiten wie z.B. <b>[Nm]</b> ergeben sich aus den Definitionsgleichungen der jeweiligen Größen. Sofern nicht in der Aufgabenstellung gefordert, wird im Quellcode auf die explizite Verwendung von Einheiten verzichtet. Bei der Bearbeitung der Aufgabe ist dennoch kontinuierlich auf Konsistenz der Maßzahlen und Maßeinheiten zu achten. Halten Sie sich durchgehend an in der Aufgabenstellung vorgegebene Bezeichnungen und Koordinatensysteme. Falls im Code Namenskonventionen eingeführt werden, sind diese ebenfalls durchgängig einzuhalten.
#
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# Abb. R.1 zeigt einen beidseitig eingespannten heterogenen Stab. Im Bereich
# $\mbox{$ 0 \leq x < 2l $}$ befindet sich der Stab bei Raumtemperatur
# $\mbox{$ \theta_0 $}$. Ab $\mbox{$ x=2l $}$ bis zum rechten Stabende bei
# $\mbox{$ x=4l $}$ wirkt eine Wärmequelle, so dass die Temperatur
# $\mbox{$ \theta(x) $}$ im Stab den Verlauf wie in
# Abb. R.1 (rechts) annimmt. Des Weiteren greift bei $\mbox{$ x=l $}$ eine
# Einzelkraft $\mbox{$ F $}$ in Richtung der Längsachse des Stabes an.
#
# <figure>
# <div style="width: 750px; margin-left: auto;  margin-right: auto;">
#
# ![aufgstellung.png](attachment:35c822ea-821f-4e81-b0eb-2ceaccb4c39e.png)
#
# </p>
# </div>
# <figcaption>
# Abb. R.1: Beidseitig eingespannter heterogener Stab (links), Temperaturverlauf $\theta(x)$ entlang des Stabes (rechts)
# </figcaption>
# </figure>
# </span>

# %%
import sympy

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) Stellen Sie den Temperaturverlauf $\mbox{$ \theta(x) $}$ für den
#     Bereich $\mbox{$ 2l \leq x \leq 4l $}$ auf.
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 2)  Zeichnen Sie das Freikörperbild des Stabes und geben Sie die
#     Gleichgewichtsbedingung an.
#
# </span>
#
# ##
# ---

# %% [markdown]
# Gleichgewichtsbedigungen

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 3)  Wählen Sie die Lagerreaktionskraft am Stabende bei $\mbox{$ x=4l $}$ zunächst als Unbekannte und stellen Sie handschriftlich die Verschiebungsdifferentialgleichung für das Verschiebungsfeld im gesamten Stab in Abhängigkeit dieser Größe auf. Beachten Sie hierbei die verschiedenen Belastungsarten in den einzelnen Teilbereichen. Zeichnen Sie alle benötigten Freischnitte.
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 4)   Geben Sie zur Bestimmung der Unbekannten handschriftlich alle
#     nötigen Rand- und Übergangsbedingungen an.
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 5)  Lösen Sie mit SymPy die Verschiebungsdifferentialgleichungen für die
#     einzelnen Bereiche des Stabes und geben Sie alle unbekannten Größen
#     an.
#
# </span>
#
# ##
# ---

# %% [markdown]
# Verschiebungsdifferentialgleichung 1. Ordnung für $u_1$:

# %% [markdown]
# Lösen der Differentialgleichung für $u_1$:

# %% [markdown]
# Verschiebungsdifferentialgleichung 1. Ordnung für $u_2$:

# %% [markdown]
# Lösen der Differentialgleichung für $u_2$:

# %% [markdown]
# Verschiebungsdifferentialgleichung 1. Ordnung für $u_3$:

# %% [markdown]
# Lösen der Differentialgleichung für $u_3$:

# %% [markdown]
# Übergangsbedingung:

# %% [markdown]
# Lagerkraft im rechten Bereich des Stabes:

# %% [markdown]
# Lagerkraft im linken Bereich des Stabes:

# %% [markdown]
# Kontrollergebnis für die Lagerkraft im linken Bereich des Stabes:
#
# $$ \boldsymbol{F}_A = A_x \boldsymbol{e}_x = \Biggl( - F + \frac{1}{2} \frac{AE_1 \alpha (\theta_1 - \theta_0) + F}{E_1 + E_2} E_2 \Biggl) \boldsymbol{e}_x $$

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 6)  Im Folgenden sollen die Verzerrung $\mbox{$ \varepsilon(x) $}$, die
#     Spannung $\mbox{$ \sigma(x) $}$ sowie die Verschiebung
#     $\mbox{$ u(x) $}$ für die Teilbereiche $0 \leq x < l$, $l \leq x < 2l$ und $2l \leq x \leq 4l$ mit SymPy berechnet und
#     grafisch dargestellt werden. Beachten Sie hierbei die verschiedenen
#     Belastungsarten in den einzelnen Teilbereichen. Für die Querschnittsfläche $A$, die Länge $l$ und die Temperaturdifferenz
#     $\theta_1- \theta_0$ soll in den folgenden Teilaufgaben gelten:
#     $$A = 100\, \,{\rm mm^2},  \qquad l = 2.5 \, \,{\rm cm}, \qquad \Delta \tilde \theta \mathrel{\mathop:}= \theta_1 - \theta_0 = 50 \, \,{\rm K}$$
#
# </span>
#
# ##
# ---

# %% [markdown]
# ### Verzerrung $\varepsilon(x)$

# %% [markdown]
# Kontrollergebnis für die Dehnung an 3 Stellen:
#
# $$\varepsilon_1 \Big( \frac{l}{2} \Big) = - \frac{1}{2} \frac{A E_1 E_2 \alpha (\theta_1 - \theta_0) - 2 E_1 F - E_2 F}{(E_1 + E_2) E_1 A} $$
# $$\varepsilon_2 \Big( \frac{3l}{2} \Big) = - \frac{1}{2} \frac{A E_1 \alpha (\theta_1 - \theta_0) + F}{(E_1 + E_2) E_1 A} E_2$$
# $$\varepsilon_3 (3l) = \frac{1}{2} \frac{A E_1 \alpha (\theta_1 - \theta_0) - F}{(E_1 + E_2) A} $$

# %% [markdown]
# ### Spannung $\sigma(x)$

# %% [markdown]
# Definition der Parameter und importieren der SymPy plotting library:

# %%
l_value =
E_steel = 
E_alu = 
alpha_steel = 
alpha_alu = 
F_I =
F_II =

from sympy.plotting import plot

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 6) 1)   Zunächst wird ein Stab aus Aluminium mit den Materialparametern aus Tab. 1 gewählt. Stellen Sie die Verläufe dar für <br>
#         i) $\mbox{$ F_{I} = 200 \, \,{\rm N}  $}$ und <br>
#         ii) $\mbox{$ F_{II}= 4000\, \,{\rm N} $}$ <br>
#         Was fällt Ihnen auf?
# </span>
#
# ##
# ---

# %% [markdown]
# ### i) Stab aus Aluminium mit $F_I = 200$N
# Liste mit Substitutionen für die vorliegende Aufgabe:

# %% [markdown]
# #### <b>Verschiebung</b>

# %% [markdown]
# #### <b>Verzerrung</b>

# %% [markdown]
# #### <b>Spannung</b>

# %% [markdown]
# ### ii) Stab aus Aluminium mit $F_{II} = 4000$N
# Liste mit Substitutionen für die vorliegende Aufgabe:

# %% [markdown]
# #### <b>Verschiebung</b>

# %% [markdown]
# #### <b>Verzerrung</b>

# %% [markdown]
# #### <b>Spannung</b>

# %% [markdown]
# <b>Interpretation der Ergebnisse: </b> <br>
#
# Interpretation der Ergebnisse

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 6) 2) Für die angreifende Kraft gilt im Folgenden $\mbox{$ F = 200 \, \,{\rm N}  $}$. <br>
# i) In einem nächsten Schritt wird für den Bereich $\mbox{$ 0 \leq x < 2l $}$ Stahl und für $\mbox{$ 2l \leq x \leq 4l $}$ Aluminium als Material verwendet. Stellen Sie die Verläufe für $\mbox{$ \varepsilon(x) $}$, $\mbox{$ \sigma(x) $}$ und $\mbox{$ u(x) $}$ dar. <br>
# ii) Abschließend soll die Materialpaarung umgekehrt werden, d.h. für den linken Bereich wird Aluminium und für den rechten Bereich Stahl verwendet. Stellen Sie auch hierfür die Verläufe für die Verschiebung, Dehnung und Spannung dar. Welche Unterschiede stellen Sie in den Verläufen fest? Begründen Sie Ihre Antworten.
# <figure>
# <table>
#   <thead>
#     <tr>
#       <th>Material         </th>
#       <th>Elastizitätsmodul $E\,[\,{\rm GPa}]$</th>
#       <th>Ausdehnungskoeffizient  $\alpha\,[10^{-6}\,{\rm K}^{-1}]$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Stahl</td>
#       <td> 210</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <td>Aluminium</td>
#       <td>70</td>
#       <td>23</td>
#     </tr>
#   </tbody>
# </table>
# <figcaption>Tabelle 1: Materialeigenschaften von Stahl und Aluminium</figcaption>
# </figure>
#
# ##
# ---

# %% [markdown]
# ### i) Stab aus Stahl und Aluminium mit $F_I = 200 N$
# Liste mit Substitutionen für die vorliegende Aufgabe:

# %% [markdown]
# #### <b>Verschiebung</b>

# %% [markdown]
# #### <b>Verzerrung</b>

# %% [markdown]
# #### <b>Spannung</b>

# %% [markdown]
# ### ii) Stab aus Aluminium und Stahl mit $F_{I} = 200N$
# Liste mit Substitutionen für die vorliegende Aufgabe:

# %% [markdown]
# #### <b>Verschiebung</b>

# %% [markdown]
# #### <b>Verzerrung</b>

# %% [markdown]
# #### <b>Spannung</b>
