# %% [markdown]
# <h1> Technische Mechanik I - WS 24/25</h1>
#
# <h2> Rechneraufgabe Übungsblatt 12 </h2>
#
# <h3> Institut für Technische Mechanik (Prof. Böhlke) </h3>
#
# <h4> Karlsruher Institut für Technologie (KIT) </h4>
#
# <b>Allgemeine Hinweise zur Bearbeitung von Rechnerhausaufgaben:</b>
#
# Alle verwendeten Einheiten sind <b>[N]</b> für Kräfte und <b>[mm]</b> (in dieser Aufgabe) für Längen. Abgeleitete Einheiten wie z.B. <b>[Nm]</b> ergeben sich aus den Definitionsgleichungen der jeweiligen Größen. Sofern nicht in der Aufgabenstellung gefordert, wird im Quellcode auf die explizite Verwendung von Einheiten verzichtet. Bei der Bearbeitung der Aufgabe ist dennoch kontinuierlich auf Konsistenz der Maßzahlen und Maßeinheiten zu achten. Halten Sie sich durchgehend an in der Aufgabenstellung vorgegebene Bezeichnungen und Koordinatensysteme. Falls im Code Namenskonventionen eingeführt werden, sind diese ebenfalls durchgängig einzuhalten.
#
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# <figure>
# <div style="width: 450px; margin-left: auto;  margin-right: auto;">
#
# ![ueb12.png](attachment:997b377c-8afb-43de-b0d8-9542309fefce.png)
#
# </p>
# </div>
# <figcaption>Abb. R.1: Seil mit verteilter Last</em></figcaption>
# </figure>
#
# An dem in Abb. R.1 gezeigten Seil greift eine lineare verteilte Last mit den Eigenschaften
# $$q(0)=0,\quad q(\pm l)=q_0$$ an. Die Neigung des Seils im Punkt
# $O$ ist Null und die Höhe der Seilkurve an den beiden Rändern ist
# $h$.
#
# </span>
#
# ---

# %%
import sympy

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 1.  Berechnen Sie die Streckenlast $q(x)$. Bestimmen Sie dabei für jeden
#     Bereich eine eigenständige Funktion.
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 2.  Geben Sie die Differentialgleichung der Seilkurve für die
#     Bereiche $(-l, 0)$ und $(0,l)$ an.
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 3.  Geben Sie Rand- und Übergangsbedingungen an, die Sie zur Lösung der
#     Differentialgleichungen nutzen können.
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 4.  Berechnen Sie die Seilkurve $y$ als Funktion von $x$ in Abhängigkeit
#     der Horizontalkraft $H(x)=H_0$.
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 5.  Berechnen Sie die Horizontalkraft $H_0$.
# </span>

# %% [markdown]
# **Kontrollwert:** $H_0 = \frac{q_0l^2}{6h}$

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 6.  Berechnen Sie die Seilkraft $S(x)$ als stückweise stetig definierte
#     Funktion. Stellen Sie anschließend $S(x)$ für
#     $q_0=500\,\,{\rm N/m}$, $h=8\,\,{\rm m}$ und $l=15\, \,{\rm m}$
#     graphisch dar. Wie groß ist der maximale Betrag der Seilkraft?
#
# </span>
#
# ##
# ---

# %% [markdown]
# Berechnung der Seilkraft:

# %% [markdown]
# Definition des Beispiels:

# %% [markdown]
# Visuelle Darstellung:

# %%
from sympy.plotting import plot

# %% [markdown]
# **Kontrollwert:** $S_{max} = 4422.178656$

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 7.  Stellen Sie die Seilkurve unter Verwendung der in Teilaufgabe 6
#     gegebenen Parameter graphisch dar. Berechnen Sie anschließend die
#     Seillänge des verwendeten Seils.
# </span>
#
# ##
# ---

# %% [markdown]
# Berechnen Sie die Seillänge mithilfe von Integration. **Hinweis:** Nutzen Sie den Befehl `evalf` um den numerischen Wert auszugeben:
