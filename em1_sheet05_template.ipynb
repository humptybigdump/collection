# %% [markdown]
# <h1> Engineering Mechanics I - Winter Semester 24/25</h1>
#
# <h2> Python Sheet 5 </h2>
#
# <h3> Institut für Technische Mechanik (Prof. Böhlke) </h3>
#
# <h4> Karlsruhe Institute of Technology (KIT) </h4>
#
# <b>General Notes on Working with Computer-Based Homework:</b>
#
# All units used are <b>[N]</b> for forces and <b>[mm]</b> (in this task) for lengths. Derived units such as <b>[Nm]</b> are determined based on the defining equations of the respective quantities. Unless explicitly required in the task description, units are not explicitly used in the source code. However, consistency of numerical values and units should be maintained throughout the task. Adhere strictly to the designations and coordinate systems specified in the task description. If naming conventions are introduced in the code, these must also be consistently followed.
#
# **New SymPy Commands**: `Symbol`, `solve`, `subs`, `Eq`, lists
# $[\ldots]$.
#
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# The front half of a sawbuck shown in Figure 1, consisting of legs 1 and 2, is partially loaded with the weight force $G$ by a round log. The sawbuck has dimensions $a$, $b$, and $l$. The two massless legs form an angle of $2\alpha$ and are connected by a massless rope between points B and C. Gravitational acceleration $g$ acts on it.\
# *Note*: Throughout the task, only the depicted front half of the sawbuck should be considered.
#
# <figure>
# <div style="width: 45%; margin-left: auto;  margin-right: auto;">
# <p>
#
# ![image.png](attachment:ffed63d1-5762-4194-b21c-b887917e1f4c.png)
#
# </p>
#
# </div>
# <figcaption>Figure 1: Half of the sawbuck, loaded with partial weight force $G$</figcaption>
# </figure>
#
# Work through the following sub-tasks.
#
# </span>

# %%
import sympy as sympy

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) Isolate legs 1 and 2, as well as the round log and the rope, and **draw by hand** the four complete free-body diagrams. Replace the connecting bolts at points A through C with the support reaction forces acting there. Additionally, assume that only forces perpendicular to each leg can be transmitted at the contact points of the round log. Therefore, introduce these reaction forces as forces oriented perpendicular to each respective leg.
#
# </span>

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 2) Represent all force quantities **three-dimensionally** in vector form. Take into account the necessary angular relationships for the normal forces.
#
# </span>

# %% [markdown]
# Definition of symbols

# %% [markdown]
# Definition of vectors

# %%
null_vector = sympy.Matrix([0,0,0]);

A = 
B = 
C =
D =
E =
G_K = 
N_1 =
N_2 =
# Out:
#   Cell In[2], line 3
#     A =
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 3) Represent the equilibrium conditions in each subsystem for the forces in vector form. Additionally, formulate the equilibrium conditions for the moments with respect to point A as scalar equations.
#
# </span>

# %% [markdown]
# Force equilibrium of system 1 (leg 1):

# %%
force_equilibrium_1 =

# %% [markdown]
# System 2 (leg2):

# %% [markdown]
# System 3 (round log):

# %% [markdown]
# System 4 (rope):

# %% [markdown]
# Additional moment equilibrium equations

# %%
moment_equilibrium_1 =

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 4) Solve all scalar equations extracted from the vector equilibrium conditions symbolically using the command `solve`.
#
# </span>

# %% [markdown]
# Definition of system of equations

# %%
equations =

# %% [markdown]
# Definition of set of unknowns

# %%
unnkowns =

# %% [markdown]
# Solving sysem of equations

# %%
solutions =

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 5) Calculate all reaction forces, taking into account the units for the following dimensions of the sawbuck and the mass of the round log acting on the depicted half of the sawbuck, $m_0$:\
# $a=0.7\,{\rm m}$, $b=0.45\,{\rm m}$, $l=1.2\,{\rm m}$, $\alpha=10$°,
# $m_0=100\,{\rm kg}$, $g\approx9.81 \,{\rm m/s^2}$.
#
# </span>

# %% [markdown]
# Definitions of the numerical example as a list of substitutions

# %% [markdown]
# Evaluation of the reaction forces

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 6) Calculate the maximum allowable mass $m_0$ of the round log if the rope must not be subjected to more than $2\,{\rm kN}$.
#
# </span>

# %% [markdown]
# Definition der maximal zulässigen Seilkraft und aufstellen eines Definition of the maximum allowable rope force and formulation of a system of equations

# %%
C_max =
