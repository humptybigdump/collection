# %% [markdown]
# <h1> Technische Mechanik I - WS 24/25</h1>
#
# <h2> Rechneraufgabe Übungsblatt 8</h2>
#
# <h3> Institut für Technische Mechanik (Prof. Böhlke) </h3>
#
# <h4> Karlsruher Institut für Technologie (KIT) </h4>
#
# <b>Allgemeine Hinweise zur Bearbeitung von Rechnerhausaufgaben:</b>
#
# Alle verwendeten Einheiten sind <b>[N]</b> für Kräfte und <b>[mm]</b> (in dieser Aufgabe) für Längen. Abgeleitete Einheiten wie z.B. <b>[Nm]</b> ergeben sich aus den Definitionsgleichungen der jeweiligen Größen. Sofern nicht in der Aufgabenstellung gefordert, wird im Quellcode auf die explizite Verwendung von Einheiten verzichtet. Bei der Bearbeitung der Aufgabe ist dennoch kontinuierlich auf Konsistenz der Maßzahlen und Maßeinheiten zu achten. Halten Sie sich durchgehend an in der Aufgabenstellung vorgegebene Bezeichnungen und Koordinatensysteme. Falls im Code Namenskonventionen eingeführt werden, sind diese ebenfalls durchgängig einzuhalten.
#
# **Neue  SymPy-Befehle**: `integrate`, `diff`, `Symbol`, `dsolve`, `simplify`, `evalf`
#
#
# ---

# %% [markdown]
# # Teil 1
#
# <span style="font-family:serif; font-size:1.5em;">
#
# Gegeben ist eine mit Schüttgut der konstanten Höhe $h$ gefüllte Schubkarre (siehe
#
# <figure id="tm1_20110824_aufg2">
# <div style="width: 65%; margin-left: auto;  margin-right: auto;">
#
# ![ueb09.png](attachment:eb354453-d553-4978-9020-196d05453bc6.png)
#
# <figcaption> Abb. R.2: Mit Schüttgut gefüllte Schubkarre</figcaption>
# </div>
#
# </figure>
#
# Die Schubkarrenwanne der Höhe $H$ hat den Abstand $d$ zum Untergrund. Die Länge der Wanne an der Oberseite ist $L$, an der
# Unterseite $L_0$. Die Breite der Schubkarre ist $T=\mathrm{konst}$. Die
# Oberkante ist radseitig gegenüber dem Wannenboden um den Überstand $a$
# versetzt. Das Schüttgut besitze eine mit der Höhe $h$ linear zunehmende
# Dichte $\rho$. Für die Höhe $h=0$ hat das Schüttgut die Dichte $\rho_0$
# und für die Höhe $h=H$ die Dichte $\rho_1$. Die Schubkarre kann um einen
# Winkel $\phi \geq 0$ gekippt werden. Gehen Sie von einer auch im
# gekippten Zustand konstanten Schüttguthöhe aus, das heißt das Schüttgut
# kann als Festkörper aufgefasst werden (z.B. ausgehärteter Zement). Die
# Masse der Schubkarre sei gegenüber der des Schüttguts vernachlässigbar.
#
# <figure id="tm1_20110826_aufg2">
# <div style="width: 40%; margin-left: auto;  margin-right: auto;">
#
# ![image.png](attachment:d49667a5-a6f3-47a5-8abe-3e6b016e1869.png)
# <figcaption> Abb. R.3: Rotation um die z-Achse</figcaption>
# </div>
#
# </figure>
#
# 1) Berechnen Sie für $\phi=0$ die von der Füllhöhe $h$ abhängigen
# Koordinaten $x_M(h)$ und $y_M(h)$ des Massenmittelpunktes des Systems
# bezüglich des gegebenen Koordinatensystems.\
# *Kontrollergebnis für die Masse des Schüttguts für die Füllhöhe $h=H$:*
# $$
# m(H) = \frac{TH}{6}\left( L\left(\varrho_0 + 2\varrho_1\right) + L_0\left( 2\varrho_0 + \varrho_1\right) \right)
# $$
#
# </span>
#
# ---

# %% [markdown]
# Definition der Massendichte

# %% [markdown]
# Integrationsgrenzen und Berechnung der Masse.

# %% [markdown]
# Bestimmung der Koordinaten des Massenmittelpunktes
