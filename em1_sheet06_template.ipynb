# %% [markdown]
# <h1> Engineering Mechanics I - Winter Term 24/25</h1>
#
# <h2> Python Sheet 6 </h2>
#
# <h3> Institut für Technische Mechanik (Prof. Böhlke) </h3>
#
# <h4> Karlsruhe Institute of Technology (KIT) </h4>
#
# <b>General Guidelines for Completing Computer Exercises:</b>
#
# All units used are <b>[N]</b> for forces and <b>[mm]</b> (in this task) for lengths. Derived units, such as <b>[Nm]</b>, are determined by the defining equations of the respective quantities. Unless explicitly required in the task, units are not used explicitly in the source code. Nevertheless, ensure consistency of numerical values and units throughout the task. Consistently follow the designations and coordinate systems provided in the task statement. If naming conventions are introduced in the code, they should be applied consistently.
#
# **New SymPy Commands:** `diff`, `piecewise`, `dsolve`, `plot`.
#
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# <figure id="rha_fig1">
# <div style="width: 95%; margin-left: auto; margin-right: auto;">
#
# ![image.png](attachment:9d440f1b-139e-47b6-877f-db80521cd69d.png)
#
# <figcaption><span id="rha_fig1" label="rha_fig1"></span> Fig. R.1: Beam with
# Distributed Load <span class="math inline"><em>q</em>(<em>x</em>)</span>
# (left) and Beam with Point Load <span class="math inline"><em>F</em></span> and Point Moment <span
# class="math inline"><em>M</em></span> (right)</figcaption>
# </div>
# </figure>
# </span>

# %%
import sympy as sympy

# %% [markdown]
# # Subtask 1
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) Given is the beam shown on the left in Fig. R.1, which is subjected to the distributed load $$q(x)=\frac{q_0}{2}\cos\left(\pi\frac{2x-l}{l}\right)+q_0\left(\frac{2x}{l}-1\right)^2.$$ Solve the following tasks for this system.
#
# </span>
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) Calculate the support reactions at supports $A$ and $B$ by solving a system of equations derived from the equilibrium conditions in SymPy. Draw the necessary free-body diagrams (on paper).
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) 2) Calculate the shear force distribution $Q_z(x)$ and the bending moment distribution $M_y(x)$ by integrating the differential equations of internal forces. **Hint**: Set up a system of differential equations and initially solve it without boundary conditions using the `dsolve` command. Then choose appropriate boundary conditions and solve the extended system again with `dsolve`.
#
# </span>
#
# ##
# ---

# %% [markdown]
# **Hint:** In this task, the differential equations must first be solved without boundary conditions. Then determine the boundary conditions using `solve`.

# %% [markdown]
# **Substitute Integration Constants**

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) 3) Verify your solution by calculating the internal forces at the boundaries and comparing them with the support reactions calculated in 1.A). Specify the necessary conditions for this verification (on paper).
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 1) 4) Plot the distributions of the distributed load, shear force, and moment for $l=1\text{m}$ and $q_0=200\text{N/m}$.
#
# </span>
#
# ##
# ---

# %% [markdown]
# **Visualization of Distributed Load**
# **Hint:** Set the function's range with the tuple `(x,0,1)`. The tuple should follow the function directly.

# %% [markdown]
# # Subtask 2
# <span style="font-family:serif; font-size:1.5em;">
#
# 2) Given is the beam shown on the right in Fig. R.1, loaded by a point force $F$ at $x = l/4$ and a point moment $M$ at $x = l/2$.
#    Solve the following tasks for this system.
#
# </span>
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 2.1 Calculate the support reactions at supports $A$ and $B$ **by hand**. Draw the necessary free-body diagrams (on paper).
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 2) 2) Calculate the shear force distribution $Q_z(x)$ and the bending moment distribution $M_y(x)$ from the equilibrium conditions **by hand**.
# Draw the necessary free-body diagrams (on paper).
#
# </span>
#
# ##
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 2) 3) Visualize the shear force and moment distribution for $l=1\text{m},F=100 \text{N}$, and $M=50\text{Nm}$.
#
# </span>
#
# ##
# ---

# %% [markdown]
# # Subtask 3
# <span style="font-family:serif; font-size:1.5em;">
#
# 3) Due to the linearity of the underlying differential equations, the **superposition principle** applies. The individual solutions of the two loading cases can be superimposed to form an overall solution. <br> Example: Superposition of the shear force distributions for the systems in Fig. R.1 left and right: $Q_z^{\rm LR}(x) = Q_z^{\rm L}(x) + Q_z^{\rm R}(x)$ <br> Solve the following tasks for the combined system.
#
# </span>
#
# ---

# %% [markdown]
# <span style="font-family:serif; font-size:1.5em;">
#
# 3) 1) Visualize the shear force distribution $Q_z^{\rm LR}(x)$ and the bending moment distribution $M_y^{\rm LR}(x)$ for the combined system using the internal forces determined in Task 1.B) and Task 2.B), along with the values specified in Task 1.D) and Task 2.C).
#
# </span>
#
# ##
# ---
